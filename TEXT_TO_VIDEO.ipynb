# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/video-generator/blob/main/TEXT_TO_VIDEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this project, I made videos using specific prompts. I used tools like snapshot_download from Hugging Face Hub, pipeline from modelscope.pipelines, OutputKeys from modelscope.outputs, and pathlib. The model that did the heavy lifting is called "damo-vilab/modelscope-damo-text-to-video-synthesis," and it works through a process called "text-to-video-synthesis." Once everything was set up, I just had to give it a written prompt, and the model created the video based on tha

# %%
# !pip install modelscope==1.4.2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 24.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install open_clip_torch -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 19.3 MB/s eta 0:00:00

# %%
# !pip install pytorch-lightning -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.4/840.4 kB 15.9 MB/s eta 0:00:00

# %%
import pickle
import pathlib
from huggingface_hub import snapshot_download
from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys
# Out:
# 2024-02-20 05:36:00,400 - modelscope - INFO - PyTorch version 2.1.0+cu121 Found.
# 2024-02-20 05:36:00,424 - modelscope - INFO - TensorFlow version 2.15.0 Found.
# 2024-02-20 05:36:00,428 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2024-02-20 05:36:00,430 - modelscope - INFO - No valid ast index found from /root/.cache/modelscope/ast_indexer, generating ast index from prebuilt!
# 2024-02-20 05:36:00,525 - modelscope - INFO - Loading done! Current index file version is 1.4.2, with md5 2cb164af86e237e4b769f2a62252a232 and a total number of 842 components indexed

# %%
# Download the model snapshot
model_dir = pathlib.Path('weights')
snapshot_download('damo-vilab/modelscope-damo-text-to-video-synthesis', repo_type='model', local_dir=model_dir)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# configuration.json:   0%|          | 0.00/1.07k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# VQGAN_autoencoder.pth:   0%|          | 0.00/5.21G [00:00<?, ?B/s]
# open_clip_pytorch_model.bin:   0%|          | 0.00/3.94G [00:00<?, ?B/s]
# text2video_pytorch_model.pth:   0%|          | 0.00/5.65G [00:00<?, ?B/s]
# ...

# %%
# Load the pipeline
pipe = pipeline('text-to-video-synthesis', model_dir.as_posix())
# Out:
# 2024-02-20 05:38:15,979 - modelscope - INFO - initiate model from weights
# 2024-02-20 05:38:15,980 - modelscope - INFO - initiate model from location weights.
# 2024-02-20 05:38:15,985 - modelscope - INFO - initialize model from weights
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-02-20 05:39:59,448 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-02-20 05:39:59,462 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-02-20 05:39:59,469 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'weights'}. trying to build by task and model information.
# ...

# %%
test_text = {
        'text': 'A panda eating bamboo on a rock.',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2024-02-20 05:40:09,727 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# 2024-02-20 05:41:09,110 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# output_video_path: /tmp/tmp8lu3oyb8.mp4

# %%
from google.colab import files

# Assuming output_video_path is the correct path to your video file
files.download(output_video_path)

# %%
test_text = {
        'text': 'A boy walking in landon.',
    }
output_video_path = pipe(test_text,)[OutputKeys.OUTPUT_VIDEO]
print('output_video_path:', output_video_path)
# Out:
# 2024-02-20 05:41:52,974 - modelscope - WARNING - task text-to-video-synthesis input definition is missing
# 2024-02-20 05:42:52,691 - modelscope - WARNING - task text-to-video-synthesis output keys are missing
# output_video_path: /tmp/tmprw6uaxj6.mp4

# %%
# Assuming output_video_path is the correct path to your video file
files.download(output_video_path)
